# %%
# Importing modules

import pandas as pd
import numpy as np

# %%
# Read the data

df = pd.read_csv(r'C:\Users\shaur\OneDrive\Desktop\Scaler\Data Cleaning\NFL Play by Play 2009-2017 (v4).csv', low_memory = False)

# %%
np.random.seed(0)

# %%
df.head()
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...

# %% [markdown]
# ## Handling Missing Values

# %%
missing_value_count = df.isnull()

# %%
missing_value_count
# Out:
#          Date  GameID  Drive    qtr   down   time  TimeUnder  TimeSecs  \
# 0       False   False  False  False   True  False      False     False
# 1       False   False  False  False  False  False      False     False
# 2       False   False  False  False  False  False      False     False
# 3       False   False  False  False  False  False      False     False
# 4       False   False  False  False  False  False      False     False
# ...       ...     ...    ...    ...    ...    ...        ...       ...
# 407683  False   False  False  False   True  False      False     False
# 407684  False   False  False  False  False  False      False     False
# 407685  False   False  False  False  False  False      False     False
# 407686  False   False  False  False  False  False      False     False
# 407687  False   False  False  False   True  False      False     False
#
#         PlayTimeDiff  SideofField  ...  yacEPA  Home_WP_pre  Away_WP_pre  \
# ...

# %%
missing_value_count = df.isnull().sum()

# %%
missing_value_count
# Out:
# Date             0
# GameID           0
# Drive            0
# qtr              0
# down         61154
#              ...
# Win_Prob     25009
# WPA           5541
# airWPA      248501
# yacWPA      248762
# Season           0
# Length: 102, dtype: int64

# %%
missing_value_count[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %% [markdown]
# #### The null values are huge, to get an idea of how much our data is having null values let's analyse the % stats.

# %%
# Total number of rows and columns

df.shape
# Out:
# (407688, 102)

# %%
total_cells = np.product(df.shape)

total_cells
# Out:
# 41584176

# %%
total_missing = missing_value_count.sum()

total_missing
# Out:
# 10342875

# %%
percent_missing = (total_missing/total_cells)*100
percent_missing
# Out:
# 24.87214126835169

# %% [markdown]
# #### Observations - 24% of our data is filled with Null Values

# %% [markdown]
# #### Analysis - Is this value missing because it wasn't recorded or because it doesn't exist?
#
# If a value it is missing becuase it doesn't exist then it doesn't make sense to try and guess what it might be.
# If a value is missing because it wasn't recorded, then you can try to guess - Imputation

# %%
missing_value_count[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %%
# From the documentation the field 'TimeSecs' column has information on the number of seconds left in the game when the play was made. This means that these values are probably missing because they were not recorded.
# Fields like "PenalizedTeam" that also have lot of missing fields. In this case, the field is missing because if there was no penalty then it doesn't make sense to say which team was penalized.

# %% [markdown]
# ### Drop the Nulls

# %%
#Remove all the rows that contain a missing value

df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
# Remove all columns with at least one missing value

columns_with_na_dropped = df.dropna(axis = 1)
columns_with_na_dropped.head(10)
# Out:
#          Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0  2009-09-10  2009091000      1    1         15        0       0
# 1  2009-09-10  2009091000      1    1         15       10       5
# 2  2009-09-10  2009091000      1    1         15        5       2
# 3  2009-09-10  2009091000      1    1         14        8       2
# 4  2009-09-10  2009091000      1    1         14        8       2
# 5  2009-09-10  2009091000      2    1         14       10       0
# 6  2009-09-10  2009091000      2    1         13       10       4
# 7  2009-09-10  2009091000      2    1         13        6       2
# 8  2009-09-10  2009091000      2    1         12        8       2
# 9  2009-09-10  2009091000      3    1         12       10       3
#
#    PlayAttempted  Yards.Gained  sp  ...  Timeout_Indicator  Timeout_Team  \
# 0              1            39   0  ...                  0          None
# 1              1             5   0  ...                  0          None
# ...

# %%
# Number of columns dropped

print('Columns in Original Dataset: %d' % df.shape[1])
print('Columns in Dropped Nulls Dataset: %d' % columns_with_na_dropped.shape[1])
# Out:
# Columns in Original Dataset: 102
# Columns in Dropped Nulls Dataset: 41

# %% [markdown]
# ### Successfully removed all the NaN's from the data !

# %% [markdown]
# ## Filling the Missing Values

# %%
subset_nfl_data = df.loc[:,'EPA':'Season'].head()
subset_nfl_data
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474       NaN       NaN     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760       NaN       NaN     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796       NaN       NaN     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712       NaN       NaN    2009

# %%
subset_nfl_data.fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474  0.000000  0.000000     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  0.000000  0.000000     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758  0.000000  0.000000    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.000000  0.000000    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %%
subset_nfl_data.fillna(method = 'bfill',axis = 0).fillna(0, inplace=True)

# %%
subset_nfl_data.isnull().sum()
# Out:
# EPA             0
# airEPA          1
# yacEPA          1
# Home_WP_pre     0
# Away_WP_pre     0
# Home_WP_post    0
# Away_WP_post    0
# Win_Prob        0
# WPA             0
# airWPA          1
# yacWPA          1
# Season          0
# dtype: int64
